# %% [markdown]
# # Scraping Gold Price using Python
#
# Data Source : [Gold Price Today](https://www.goodreturns.in/gold-rates/mumbai.html)
# <br> <br>
# ![Imgur](https://imgur.com/xDcfcQj.jpg)
# <br>

# %% [markdown]
# ## Web Scraping
#
# >### What is Web Scraping?
# **Web Scraping** is the process through which we extract data from a website, and save it in a form which is easy to read, to understand and to work on.
#
# >When we say 'Easy to work on', we mean to say that the data thus extracted can be used to get a lot of useful insights and answer a lot of questions, finding answers to which would not be such an easy task, if we did not have that data stored with us in a simple and sorted manner, i.e. generally in an ` Excel File or a CSV file`.
#
# >### How does web scraping work?
#
# ![](https://imgur.com/8xgzOus.png)
#
# >In order to understand web scraping, it's important to first understand that web pages which are built using text-based mark-up languages and the most common being used is`HTML`.
#
# >The HyperText Markup Language or HTML is the standard markup language for documents designed to be displayed in a web browser. It can be assisted by technologies such as Cascading Style Sheets and scripting languages such as JavaScript.
# **Note**  : Not all websites allow Web Scraping, especially when it comes to user's personal data, so we always have to make sure that we are not publishing any personal data of user online.
# Websites usually have protection and if they see that we are downloading a large amount of data from their website, they will block us from accessing the website.

# %% [markdown]
# ### About Good Returns
#
# ![](https://imgur.com/cT2nhZ4.png?1)
#
# GoodReturns.in is a leading business news and personal finance portal of Oneindia.com (Greynium Information Technologies Pvt. Ltd.). GoodReturns.in provides live news updates and in-depth analyses of major developments in India and abroad.
#
# We cover every important aspect of business news, including stock markets, currency, economy, crude oil movement, gold, debt market, etc. The portal publishes content in six languages – English, Hindi, Malayalam, Tamil, Kannada and Telugu. The content we generate is available on desktop, mobile web and mobile apps. We focus on keeping up with the current and trending topics and produce original content to give a fresh perspective to our readers. Content of Goodreturns.in also includes editorial columns, opinions and analytical stories.
#
# Our database pages include currency converter, bank holidays, gold rates, FD comparison and in certain categories, we are the leaders in price dissemination
#
# Read more at: https://www.goodreturns.in/aboutus.html

# %% [markdown]
# ### Project Idea
#
# In this project, we will parse through the Gold Returns's website to get details about the Gold Rates in the top cities of INDIA.
#
# We will retrieve information from the page **’Gold Rate in Top Cities of India’** using _web scraping_: the process of programmatically retrieving information from the web. Web scraping is not magic, and yet some readers can get information every day. For example, a recent graduate can copy and paste information about the companies they are applying to into a job application management spreadsheet.

# %% [markdown]
# ### Project Goal
#
# The goal of the project is to create a web scraper that takes all the required information and compiles it into a CSV. The output CSV file format is given below:
# ![](https://imgur.com/ySWxZoj.png?1)

# %% [markdown]
# ### Project steps
# Here is an outline of the steps we'll follow :
#
# 1. Download the webpage using `requests`
# 2. Parse the HTML source code using `BeautifulSoup` library and extract the desired information
# 3. Building the scraper components
# 4. Compile the extracted information into Python list and dictionaries
# 5. Converting the python dictionaries into `Pandas DataFrames`
# 5. Write information to the final CSV file
# 7. Future work and references

# %% [markdown]
# >### Packages Used:
# >1. Requests — For downloading the HTML code from the IMDB URL
# >2. BeautifulSoup4 — For parsing and extracting data from the HTML string
# >3. Pandas — to gather my data into a dataframe for further processing

# %% [markdown]
# ### How to run the code
#
# This tutorial is an executable [Jupyter notebook](https://jupyter.org) hosted on [Jovian](https://www.jovian.ai). You can _run_ this tutorial and experiment with the code examples in a couple of ways: *using free online resources* (recommended) or *on your computer*.
#
# #### Option 1: Running using free online resources (1-click, recommended)
#
# The easiest way to start executing the code is to click the **Run** button at the top of this page and select **Run on Binder**. You can also select "Run on Colab" or "Run on Kaggle", but you'll need to create an account on [Google Colab](https://colab.research.google.com) or [Kaggle](https://kaggle.com) to use these platforms.
#
#
# #### Option 2: Running on your computer locally
#
# To run the code on your computer locally, you'll need to set up [Python](https://www.python.org), download the notebook and install the required libraries. We recommend using the [Conda](https://docs.conda.io/projects/conda/en/latest/user-guide/install/) distribution of Python. Click the **Run** button at the top of this page, select the **Run Locally** option, and follow the instructions.
#
# >  **Jupyter Notebooks**: This tutorial is a [Jupyter notebook](https://jupyter.org) - a document made of _cells_. Each cell can contain code written in Python or explanations in plain English. You can execute code cells and view the results, e.g., numbers, messages, graphs, tables, files, etc., instantly within the notebook. Jupyter is a powerful platform for experimentation and analysis. Don't be afraid to mess around with the code & break things - you'll learn a lot by encountering and fixing errors. You can use the "Kernel > Restart & Clear Output" menu option to clear all outputs and start again from the top.

# %% [markdown]
# ## Lets begin :

# %% [markdown]
# >Note : We will use the `Jovian` library and its `commit()` function throughout the code to save our progress as we move along.

# %%
# !pip install jovian --upgrade --quiet
import jovian
# Execute this to save new versions of the notebook
jovian.commit(filename="web-scraping-project.ipynb")
# Out:
# [jovian] Updating notebook "abhishek-mehta2k/web-scraping-project" on https://jovian.ai
# [jovian] Committed successfully! https://jovian.ai/abhishek-mehta2k/web-scraping-project
# 'https://jovian.ai/abhishek-mehta2k/web-scraping-project'

# %% [markdown]
# !pip install jovian --upgrade --quiet
# import jovian
# # Execute this to save new versions of the notebook
# jovian.commit(project="web-scraping-project")

# %% [markdown]
# >#### **What is `requests`**
#
#
# >Requests is a Python HTTP library that allows us to send HTTP requests to servers of websites, instead of using browsers to communicate the web.
#
# >We use `pip`, a package-management system, to install and manage softwares. Since the platform we selected is **Binder**, we would have to type a line of code `!pip install` to install `requests`. You will see lots codes of `!pip` when installing other packages.
#
# >When we attempt to use some prewritten functions from a certain library, we would use the `import` statement. e.g. When we would have to type `import requests` after installation, we are able to use any function from `requests` library.

# %%
# !pip install requests --quiet --upgrade
import requests

# %% [markdown]
# #### **requests.get()**
#
# In order to **download a web page**, we use `requests.get()` to **send the HTTP request** to the **Good Return's server** and what the function returns is a **response object**, which is **the HTTP response**.

# %%
city_name = 'mumbai'
gold_rate_url = 'https://www.goodreturns.in/gold-rates/'+city_name+'.html'   #The URL Address of the webpage we will scrape, i.e. Gold Rate for Mumbai City
response = requests.get(gold_rate_url)      #requests.get()

# %% [markdown]
# #### **Status code**
#
# Now, we have to `check` if we succesfully send the HTTP request and get a HTTP response back on purpose. This is because we're NOT using browsers, because of which we can't get `the feedback` directly if we didn't send HTTP requests successfully.
#
# In general, the method to check out if the server sended a HTTP response back is the **status code**. In `requests` library, `requests.get` returns a response object, which containing the page contents and the information about status code indicating if the HTTP request was successful. Learn more about HTTP status codes here: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status.
#
#
# If the request was successful, `response.status_code` is set to a value between **200 and 299**.

# %%
response.status_code    #Here we are checking the Status code, -> 200-299 will mean that the request was successful
# Out:
# 200

# %% [markdown]
# The HTTP response contains HTML that is ready to be displayed in browser. Here we can use `response.text` to retrive the HTML document.

# %%
page_contents = response.text
len(page_contents)    #The `len` fucnction tells us the length of the response object
# Out:
# 417693

# %% [markdown]
# ***HOORAY*** ! We have ~4.17 Lac characters within the HTML that we have downloaded just in a second

# %%
page_contents[:500]   #This displays the first 500 characters of `page_contents`
# Out:
# '\n<!DOCTYPE html>\n<html>\n\t    <head data-content_type="database" data-gads_page="article-database">\n\n\t\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8"><title>Todays Gold Rate in Mumbai, 22 & 24 Carat Gold Price on 1st Aug 2022 - Goodreturns</title><meta name="description" content="Gold Rate in Mumbai Today (1st Aug 2022): Get 22 Carat & 24 Karat gold rate in Mumbai & last 10 days gold price based on rupees per gram from GoodReturns."/><meta name="keywords" content="gold rate in'

# %% [markdown]
# - What we see above is the source code of the web page. It is written in a language called HTML.
# - It defines and display the content and structure of the web page by the help of the browsers like Chrome

# %%
with open("gold_price_mumbai.html", 'w') as f:  #Writing the html page to a file locally, i.e. a replica of real html page
    f.write(page_contents)

# %% [markdown]
# Here, we save the text that we have got into a `HTML` file with `open` statement.
#
# Now, a HTML File is created by the name`gold_price_mumbai.html`

# %% [markdown]
# ![](https://imgur.com/hwPeN4I.png)

# %%
jovian.commit(filename="web-scraping-project.ipynb") #Saving the work done till now
# Out:
# [jovian] Updating notebook "abhishek-mehta2k/web-scraping-project" on https://jovian.ai
# [jovian] Committed successfully! https://jovian.ai/abhishek-mehta2k/web-scraping-project
# 'https://jovian.ai/abhishek-mehta2k/web-scraping-project'

# %% [markdown]
# ## Parse the HTML source code using Beautiful Soup library

# %% [markdown]
# >### What is Beautiful Soup?
#
# >Beautiful Soup is **a Python package** for **parsing HTML and XML documents**. Beautiful Soup enables us to get data out of sequences of characters. It creates a parse tree for parsed pages that can be used to extract data from HTML. It's a handy tool when it comes to web scraping. You can read more on their documentation site. https://www.crummy.com/software/BeautifulSoup/bs4/doc/#getting-help
#
# >To extract information from the HTML source code of a webpage programmatically, we can use the Beautiful Soup library. Let's install the library and import **the BeautifulSoup class** from **the bs4 module.**

# %%
# !pip install beautifulsoup4 --quiet --upgrade
from bs4 import BeautifulSoup
doc = BeautifulSoup(page_contents, 'html.parser')  #Now 'doc' contains entire html in parsed format

# %%
type(doc)
# Out:
# bs4.BeautifulSoup

# %% [markdown]
# ### Inspecting the HTML source code of a web page

# %% [markdown]
# >In Beautiful Soup library, we can specify `html.parser` to ask Python to read components of the page, instead of reading it as a long string.
#
# >### What is HTML?
# Before we dive into how to inspect HTML, we should know the basic knowledge about HTML.
#
# >The HyperText Markup Language, or HTML is the standard markup language for documents designed to be displayed in a web browser. It can be assisted by technologies such as Cascading Style Sheets and scripting languages such as JavaScript.

# %% [markdown]
# ![](https://imgur.com/2D1379B.png)

# %% [markdown]
# #### **An HTML tag comprises of three parts:**
#
# 1. **Name**: (`html`, `head`, `body`, `div`, etc.) Indicates what the tag represents and how a browser should interpret the information inside it.
# 2. **Attributes**: (`href`, `target`, `class`, `id`, etc.) Properties of tag used by the browser to customize how a tag is displayed and decide what happens on user interactions.
# 3. **Children**: A tag can contain some text or other tags or both between the opening and closing segments, e.g., `<div>Some content</div>`.
#
#
# ### Common tags and attributes
#
# #### **Tags in HTML**
#
# There are around 100 types of HTML tags but on a day to day basis, around 15 to 20 of them are the most common use, such as `<div>` tag, `<p>` tag, `<section>` tag, `<img>` tag, `<a>` tags.
#
#
# Of many tags, I wanted to highlight **`<a>` tag**, which  can contain attributes such as `href` (hyperlink reference), because `<a>` tag allows users to click and they would be directed to another site. That's why the name of `<a>` tag is  **anchor**.
#
# #### **Attributes**
#
# Each tag supports several attributes. Following are some common attributes used to modify the behavior of tags
#
# * `id`
# * `style`
# * `class`
# * `href` (used with `<a>`)
# * `src` (used with `<img>`)

# %% [markdown]
# `What we can do with **a BeautifulSoup object** is to get **a specifc types of a tag in HTML** by calling the name of a tag, as shown in code cell below.`
#
# Here, we use the `find()` function of BeautifulSoup to find the first `<title>` tag in the HTML document and display its content

# %%
title = doc.find('title')
title
# Out:
# <title>Todays Gold Rate in Mumbai, 22 &amp; 24 Carat Gold Price on 1st Aug 2022 - Goodreturns</title>

# %% [markdown]
# ### Inspecting HTML in the Browser
#
# >To view the **source code** of any webpage right within **your browser**, you can **right click** anywhere on a page and **select** the **"Inspect"** option. You access the **"Developer Tools"** mode, where you can see the source code as **a tree**. You can expand and collapse various nodes and find the source code for a specific portion of the page
#
# ![](https://imgur.com/kST0LSp.png)
#
#
# As shown in the photo above, I've cursored over the "Today 22 Carart Gold Price Per Gram in Mumbai (INR)" to display how the how the entire content was presented.
# I found out that table was present inside the `<div>` tag. And i got the specific class `class = "gold_silver_table right-align-content"`for this tag.
#
# Since I've pulled a single page and return to a BeautifulSoup object, we can start to use some function from Beautiful Soup library to withdraw the piece of information we want.

# %% [markdown]
# ### City Name
# #### Now we will use `BeautifulSoup` to extract the `Names` , `
# `Gram`,`Price` and `Change in Price` of the Gold Price Table from the HTML Page

# %%
city_name = city_name.upper()
city_name
# Out:
# 'MUMBAI'

# %% [markdown]
# ### Gold Weight

# %%
table_div = doc.find("div",{"class": "gold_silver_table right-align-content"})
table = table_div.find("table").find_all("tr")
gram = table[1].find_all("td")[0].text
gram
# Out:
# '1 gram'

# %% [markdown]
# ### Today's Price

# %%
today_price = table[1].find_all("td")[1].text.replace(",", "")
today_price
# Out:
# '₹ 4710'

# %% [markdown]
# ### Yesterday's Price

# %%
yesterday_price = table[1].find_all("td")[2].text.replace(",", "")
yesterday_price
# Out:
# '₹ 4720'

# %% [markdown]
# ### Daily Price Change

# %%
daily_price_change = table[1].find_all("td")[3].text.strip().replace(",", "")      
daily_price_change
# Out:
# '₹ -10'

# %% [markdown]
# ### Creating a DataFrame using Pandas for Lists derived till now

# %% [markdown]
# > What is **Pandas**?
#
# >Pandas is a software library written for the Python programming language for data manipulation and analysis.
# In particular, it offers data structures and operations for manipulating numerical tables and time series.
#
# >What is a **DataFrame**?
#
# >A Pandas DataFrame is a 2 dimensional data structure, like a 2 dimensional array, or a table with rows and columns.
# DataFrame makes it easier for us to work with tablular data and analse it.

# %%
# !pip install pandas --quiet --upgrade   #Installing Pandas Library
import pandas as pd

# %% [markdown]
# Now, Will create a `Python Dictionary` with the `City Name`, `Gold Weight`, `Today's Price`, `Yesterday's Price` and `Daily Price Change` that we have extracted above.

# %%
gold_price_dict = {'City' : [city_name],
                  'Gram' : [gram],
                  'Today Price' : [today_price],
                  'Yesterday Price' : [yesterday_price],
                  'Daily Price Change' : [daily_price_change]}
gold_price_dict
# Out:
# {'City': ['MUMBAI'],
#  'Gram': ['1 gram'],
#  'Today Price': ['₹ 4710'],
#  'Yesterday Price': ['₹ 4720'],
#  'Daily Price Change': ['₹ -10']}

# %%
gold_price_df = pd.DataFrame(gold_price_dict)  #Here we convert the dictionary into a Pandas DataFrame

# %% [markdown]
# Now, Let us check the Dataframe that we have created which contains the `City Name`,`Gram`,`Today Price`,`Yesterday Price` and `Daily Price Change`

# %%
gold_price_df
# Out:
#      City    Gram Today Price Yesterday Price Daily Price Change
# 0  MUMBAI  1 gram      ₹ 4710          ₹ 4720              ₹ -10

# %% [markdown]
# We can see the DataFrame consists of the `city_name` and other details
#
# Therefore, we can be sure that we have extracted the requried data
#
# ![](https://imgur.com/JuNUxbd.png)

# %% [markdown]
# We have finally created a DataFrame which contains the required information

# %%
jovian.commit(filename="web-scraping-project")
# Out:
# [jovian] Updating notebook "abhishek-mehta2k/web-scraping-project" on https://jovian.ai
# [jovian] Committed successfully! https://jovian.ai/abhishek-mehta2k/web-scraping-project
# 'https://jovian.ai/abhishek-mehta2k/web-scraping-project'

# %% [markdown]
# ## Next Steps
# ### Now, we will go into each individual `City's` page and extract the required information

# %%
city_list = ["ahmedabad","bangalore","bhubaneswar","chandigarh","chennai",
             "coimbatore","delhi","hyderabad","jaipur","kerala","kolkata",
             "lucknow","madurai","mangalore","mumbai","mysore","nagpur",
             "nashik","patna","pune","surat","vadodara","vijayawada","visakhapatnam"]
gold_price_list = []
for city_name in city_list:
    url = "https://www.goodreturns.in/gold-rates/"+city_name+".html"
    response = requests.get(url)
    if response.status_code != 200:
        raise Exception("Url",url,"not found")

    content = response.text

    doc = BeautifulSoup(content,'html.parser')

    div_22car = doc.find("div",{"class": "gold_silver_table right-align-content"})
    table = div_22car.find("table").find_all("tr")
    for data in range(1,len(table)):
        city = city_name.upper()
        gram = table[data].find_all("td")[0].text
        today_price = table[data].find_all("td")[1].text.replace(",", "")
        yesterday_price = table[data].find_all("td")[2].text.replace(",", "")
        daily_price_change = table[data].find_all("td")[3].text.strip().replace(",", "")

        gold_price_list.append({'City' : city,
                              'Gram' : gram,
                              "Today's Price" : today_price,
                              "Yesterday's Price" : yesterday_price,
                              "Daily Price Change" : daily_price_change })

# %% [markdown]
# Now we have all the required information for the gold price
# Let us see what all we have got

# %%
gold_price_list
# Out:
# [{'City': 'AHMEDABAD',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4715',
#   "Yesterday's Price": '₹ 4723',
#   'Daily Price Change': '₹ -8'},
#  {'City': 'AHMEDABAD',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 37720',
#   "Yesterday's Price": '₹ 37784',
#   'Daily Price Change': '₹ -64'},
#  {'City': 'AHMEDABAD',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47150',
#   "Yesterday's Price": '₹ 47230',
#   'Daily Price Change': '₹ -80'},
#  {'City': 'AHMEDABAD',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 471500',
#   "Yesterday's Price": '₹ 472300',
#   'Daily Price Change': '₹ -800'},
#  {'City': 'BANGALORE',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4715',
#   "Yesterday's Price": '₹ 4725',
#   'Daily Price Change': '₹ -10'},
#  {'City': 'BANGALORE',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 37720',
#   "Yesterday's Price": '₹ 37800',
#   'Daily Price Change': '₹ -80'},
#  {'City': 'BANGALORE',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47150',
#   "Yesterday's Price": '₹ 47250',
#   'Daily Price Change': '₹ -100'},
#  {'City': 'BANGALORE',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 471500',
#   "Yesterday's Price": '₹ 472500',
#   'Daily Price Change': '₹ -1000'},
#  {'City': 'BHUBANESWAR',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4710',
#   "Yesterday's Price": '₹ 4720',
#   'Daily Price Change': '₹ -10'},
#  {'City': 'BHUBANESWAR',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 37680',
#   "Yesterday's Price": '₹ 37760',
#   'Daily Price Change': '₹ -80'},
#  {'City': 'BHUBANESWAR',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47100',
#   "Yesterday's Price": '₹ 47200',
#   'Daily Price Change': '₹ -100'},
#  {'City': 'BHUBANESWAR',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 471000',
#   "Yesterday's Price": '₹ 472000',
#   'Daily Price Change': '₹ -1000'},
#  {'City': 'CHANDIGARH',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4725',
#   "Yesterday's Price": '₹ 4735',
#   'Daily Price Change': '₹ -10'},
#  {'City': 'CHANDIGARH',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 37800',
#   "Yesterday's Price": '₹ 37880',
#   'Daily Price Change': '₹ -80'},
#  {'City': 'CHANDIGARH',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47250',
#   "Yesterday's Price": '₹ 47350',
#   'Daily Price Change': '₹ -100'},
#  {'City': 'CHANDIGARH',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 472500',
#   "Yesterday's Price": '₹ 473500',
#   'Daily Price Change': '₹ -1000'},
#  {'City': 'CHENNAI',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4795',
#   "Yesterday's Price": '₹ 4815',
#   'Daily Price Change': '₹ -20'},
#  {'City': 'CHENNAI',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 38360',
#   "Yesterday's Price": '₹ 38520',
#   'Daily Price Change': '₹ -160'},
#  {'City': 'CHENNAI',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47950',
#   "Yesterday's Price": '₹ 48150',
#   'Daily Price Change': '₹ -200'},
#  {'City': 'CHENNAI',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 479500',
#   "Yesterday's Price": '₹ 481500',
#   'Daily Price Change': '₹ -2000'},
#  {'City': 'COIMBATORE',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4795',
#   "Yesterday's Price": '₹ 4815',
#   'Daily Price Change': '₹ -20'},
#  {'City': 'COIMBATORE',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 38360',
#   "Yesterday's Price": '₹ 38520',
#   'Daily Price Change': '₹ -160'},
#  {'City': 'COIMBATORE',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47950',
#   "Yesterday's Price": '₹ 48150',
#   'Daily Price Change': '₹ -200'},
#  {'City': 'COIMBATORE',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 479500',
#   "Yesterday's Price": '₹ 481500',
#   'Daily Price Change': '₹ -2000'},
#  {'City': 'DELHI',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4725',
#   "Yesterday's Price": '₹ 4735',
#   'Daily Price Change': '₹ -10'},
#  {'City': 'DELHI',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 37800',
#   "Yesterday's Price": '₹ 37880',
#   'Daily Price Change': '₹ -80'},
#  {'City': 'DELHI',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47250',
#   "Yesterday's Price": '₹ 47350',
#   'Daily Price Change': '₹ -100'},
#  {'City': 'DELHI',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 472500',
#   "Yesterday's Price": '₹ 473500',
#   'Daily Price Change': '₹ -1000'},
#  {'City': 'HYDERABAD',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4710',
#   "Yesterday's Price": '₹ 4720',
#   'Daily Price Change': '₹ -10'},
#  {'City': 'HYDERABAD',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 37680',
#   "Yesterday's Price": '₹ 37760',
#   'Daily Price Change': '₹ -80'},
#  {'City': 'HYDERABAD',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47100',
#   "Yesterday's Price": '₹ 47200',
#   'Daily Price Change': '₹ -100'},
#  {'City': 'HYDERABAD',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 471000',
#   "Yesterday's Price": '₹ 472000',
#   'Daily Price Change': '₹ -1000'},
#  {'City': 'JAIPUR',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4725',
#   "Yesterday's Price": '₹ 4735',
#   'Daily Price Change': '₹ -10'},
#  {'City': 'JAIPUR',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 37800',
#   "Yesterday's Price": '₹ 37880',
#   'Daily Price Change': '₹ -80'},
#  {'City': 'JAIPUR',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47250',
#   "Yesterday's Price": '₹ 47350',
#   'Daily Price Change': '₹ -100'},
#  {'City': 'JAIPUR',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 472500',
#   "Yesterday's Price": '₹ 473500',
#   'Daily Price Change': '₹ -1000'},
#  {'City': 'KERALA',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4710',
#   "Yesterday's Price": '₹ 4720',
#   'Daily Price Change': '₹ -10'},
#  {'City': 'KERALA',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 37680',
#   "Yesterday's Price": '₹ 37760',
#   'Daily Price Change': '₹ -80'},
#  {'City': 'KERALA',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47100',
#   "Yesterday's Price": '₹ 47200',
#   'Daily Price Change': '₹ -100'},
#  {'City': 'KERALA',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 471000',
#   "Yesterday's Price": '₹ 472000',
#   'Daily Price Change': '₹ -1000'},
#  {'City': 'KOLKATA',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4710',
#   "Yesterday's Price": '₹ 4720',
#   'Daily Price Change': '₹ -10'},
#  {'City': 'KOLKATA',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 37680',
#   "Yesterday's Price": '₹ 37760',
#   'Daily Price Change': '₹ -80'},
#  {'City': 'KOLKATA',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47100',
#   "Yesterday's Price": '₹ 47200',
#   'Daily Price Change': '₹ -100'},
#  {'City': 'KOLKATA',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 471000',
#   "Yesterday's Price": '₹ 472000',
#   'Daily Price Change': '₹ -1000'},
#  {'City': 'LUCKNOW',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4725',
#   "Yesterday's Price": '₹ 4735',
#   'Daily Price Change': '₹ -10'},
#  {'City': 'LUCKNOW',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 37800',
#   "Yesterday's Price": '₹ 37880',
#   'Daily Price Change': '₹ -80'},
#  {'City': 'LUCKNOW',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47250',
#   "Yesterday's Price": '₹ 47350',
#   'Daily Price Change': '₹ -100'},
#  {'City': 'LUCKNOW',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 472500',
#   "Yesterday's Price": '₹ 473500',
#   'Daily Price Change': '₹ -1000'},
#  {'City': 'MADURAI',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4795',
#   "Yesterday's Price": '₹ 4815',
#   'Daily Price Change': '₹ -20'},
#  {'City': 'MADURAI',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 38360',
#   "Yesterday's Price": '₹ 38520',
#   'Daily Price Change': '₹ -160'},
#  {'City': 'MADURAI',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47950',
#   "Yesterday's Price": '₹ 48150',
#   'Daily Price Change': '₹ -200'},
#  {'City': 'MADURAI',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 479500',
#   "Yesterday's Price": '₹ 481500',
#   'Daily Price Change': '₹ -2000'},
#  {'City': 'MANGALORE',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4715',
#   "Yesterday's Price": '₹ 4725',
#   'Daily Price Change': '₹ -10'},
#  {'City': 'MANGALORE',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 37720',
#   "Yesterday's Price": '₹ 37800',
#   'Daily Price Change': '₹ -80'},
#  {'City': 'MANGALORE',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47150',
#   "Yesterday's Price": '₹ 47250',
#   'Daily Price Change': '₹ -100'},
#  {'City': 'MANGALORE',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 471500',
#   "Yesterday's Price": '₹ 472500',
#   'Daily Price Change': '₹ -1000'},
#  {'City': 'MUMBAI',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4710',
#   "Yesterday's Price": '₹ 4720',
#   'Daily Price Change': '₹ -10'},
#  {'City': 'MUMBAI',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 37680',
#   "Yesterday's Price": '₹ 37760',
#   'Daily Price Change': '₹ -80'},
#  {'City': 'MUMBAI',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47100',
#   "Yesterday's Price": '₹ 47200',
#   'Daily Price Change': '₹ -100'},
#  {'City': 'MUMBAI',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 471000',
#   "Yesterday's Price": '₹ 472000',
#   'Daily Price Change': '₹ -1000'},
#  {'City': 'MYSORE',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4715',
#   "Yesterday's Price": '₹ 4725',
#   'Daily Price Change': '₹ -10'},
#  {'City': 'MYSORE',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 37720',
#   "Yesterday's Price": '₹ 37800',
#   'Daily Price Change': '₹ -80'},
#  {'City': 'MYSORE',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47150',
#   "Yesterday's Price": '₹ 47250',
#   'Daily Price Change': '₹ -100'},
#  {'City': 'MYSORE',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 471500',
#   "Yesterday's Price": '₹ 472500',
#   'Daily Price Change': '₹ -1000'},
#  {'City': 'NAGPUR',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4713',
#   "Yesterday's Price": '₹ 4723',
#   'Daily Price Change': '₹ -10'},
#  {'City': 'NAGPUR',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 37704',
#   "Yesterday's Price": '₹ 37784',
#   'Daily Price Change': '₹ -80'},
#  {'City': 'NAGPUR',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47130',
#   "Yesterday's Price": '₹ 47230',
#   'Daily Price Change': '₹ -100'},
#  {'City': 'NAGPUR',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 471300',
#   "Yesterday's Price": '₹ 472300',
#   'Daily Price Change': '₹ -1000'},
#  {'City': 'NASHIK',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4713',
#   "Yesterday's Price": '₹ 4723',
#   'Daily Price Change': '₹ -10'},
#  {'City': 'NASHIK',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 37704',
#   "Yesterday's Price": '₹ 37784',
#   'Daily Price Change': '₹ -80'},
#  {'City': 'NASHIK',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47130',
#   "Yesterday's Price": '₹ 47230',
#   'Daily Price Change': '₹ -100'},
#  {'City': 'NASHIK',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 471300',
#   "Yesterday's Price": '₹ 472300',
#   'Daily Price Change': '₹ -1000'},
#  {'City': 'PATNA',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4713',
#   "Yesterday's Price": '₹ 4723',
#   'Daily Price Change': '₹ -10'},
#  {'City': 'PATNA',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 37704',
#   "Yesterday's Price": '₹ 37784',
#   'Daily Price Change': '₹ -80'},
#  {'City': 'PATNA',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47130',
#   "Yesterday's Price": '₹ 47230',
#   'Daily Price Change': '₹ -100'},
#  {'City': 'PATNA',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 471300',
#   "Yesterday's Price": '₹ 472300',
#   'Daily Price Change': '₹ -1000'},
#  {'City': 'PUNE',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4713',
#   "Yesterday's Price": '₹ 4723',
#   'Daily Price Change': '₹ -10'},
#  {'City': 'PUNE',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 37704',
#   "Yesterday's Price": '₹ 37784',
#   'Daily Price Change': '₹ -80'},
#  {'City': 'PUNE',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47130',
#   "Yesterday's Price": '₹ 47230',
#   'Daily Price Change': '₹ -100'},
#  {'City': 'PUNE',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 471300',
#   "Yesterday's Price": '₹ 472300',
#   'Daily Price Change': '₹ -1000'},
#  {'City': 'SURAT',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4715',
#   "Yesterday's Price": '₹ 4725',
#   'Daily Price Change': '₹ -10'},
#  {'City': 'SURAT',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 37720',
#   "Yesterday's Price": '₹ 37800',
#   'Daily Price Change': '₹ -80'},
#  {'City': 'SURAT',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47150',
#   "Yesterday's Price": '₹ 47250',
#   'Daily Price Change': '₹ -100'},
#  {'City': 'SURAT',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 471500',
#   "Yesterday's Price": '₹ 472500',
#   'Daily Price Change': '₹ -1000'},
#  {'City': 'VADODARA',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4713',
#   "Yesterday's Price": '₹ 4723',
#   'Daily Price Change': '₹ -10'},
#  {'City': 'VADODARA',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 37704',
#   "Yesterday's Price": '₹ 37784',
#   'Daily Price Change': '₹ -80'},
#  {'City': 'VADODARA',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47130',
#   "Yesterday's Price": '₹ 47230',
#   'Daily Price Change': '₹ -100'},
#  {'City': 'VADODARA',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 471300',
#   "Yesterday's Price": '₹ 472300',
#   'Daily Price Change': '₹ -1000'},
#  {'City': 'VIJAYAWADA',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4710',
#   "Yesterday's Price": '₹ 4720',
#   'Daily Price Change': '₹ -10'},
#  {'City': 'VIJAYAWADA',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 37680',
#   "Yesterday's Price": '₹ 37760',
#   'Daily Price Change': '₹ -80'},
#  {'City': 'VIJAYAWADA',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47100',
#   "Yesterday's Price": '₹ 47200',
#   'Daily Price Change': '₹ -100'},
#  {'City': 'VIJAYAWADA',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 471000',
#   "Yesterday's Price": '₹ 472000',
#   'Daily Price Change': '₹ -1000'},
#  {'City': 'VISAKHAPATNAM',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4710',
#   "Yesterday's Price": '₹ 4720',
#   'Daily Price Change': '₹ -10'},
#  {'City': 'VISAKHAPATNAM',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 37680',
#   "Yesterday's Price": '₹ 37760',
#   'Daily Price Change': '₹ -80'},
#  {'City': 'VISAKHAPATNAM',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47100',
#   "Yesterday's Price": '₹ 47200',
#   'Daily Price Change': '₹ -100'},
#  {'City': 'VISAKHAPATNAM',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 471000',
#   "Yesterday's Price": '₹ 472000',
#   'Daily Price Change': '₹ -1000'}]

# %%
jovian.commit(filename="web-scraping-project.ipynb")
# Out:
# [jovian] Updating notebook "abhishek-mehta2k/web-scraping-project" on https://jovian.ai
# [jovian] Committed successfully! https://jovian.ai/abhishek-mehta2k/web-scraping-project
# 'https://jovian.ai/abhishek-mehta2k/web-scraping-project'

# %% [markdown]
# ### Now, we will write different fuctions to combine the details for any `Given Day`

# %% [markdown]
# > `install_libraries()` will install all the required libraries

# %%
def install_libraries():
    
    # !pip install jovian --upgrade --quiet
    import requests
    # !pip install Beautifulsoup4 --upgrade --quiet
    from bs4 import BeautifulSoup
    from datetime import date
    import pandas as pd
    print("Successfully installed all the required Libraries")

# %% [markdown]
# >`get_doc()` will take city_name as an input and it will porvide us with an html doc

# %%
def get_doc(city_name):
    url = "https://www.goodreturns.in/gold-rates/"+city_name+".html"
    response = requests.get(url)
    if response.status_code != 200:
        raise Exception("Url",url,"not found")

    content = response.text
    doc = BeautifulSoup(content,'html.parser')
    
    return doc

# %% [markdown]
# >`append_carat_detail()` will add the details about the particular `Carat` gold to the data

# %%
def append_carat_detail(city_name, data, table, gold_price_list):
    #For 22_Carat Gold
    carat = table[0].find_all("td",{"class": "heading"})[1].text[:8]
    city = city_name.upper()
    gram = table[data].find_all("td")[0].text
    today_price = table[data].find_all("td")[1].text.replace(",", "")
    yesterday_price = table[data].find_all("td")[2].text.replace(",", "")
    daily_price_change = table[data].find_all("td")[3].text.strip().replace(",", "")

    gold_price_list.append({'City' : city,
                        'Carat' : carat,
                      'Gram' : gram,
                      "Today's Price" : today_price,
                      "Yesterday's Price" : yesterday_price,
                      "Daily Price Change" : daily_price_change })

    return gold_price_list

# %% [markdown]
# > `list_of_dict()` will return the data for all the cities

# %%
def list_of_dict(city_list):
    gold_price_list = []
    for city_name in city_list:
        #FUNCITON CALL `get_doc()`
        doc = get_doc(city_name)
        
        div_car = doc.find_all("div",{"class": "gold_silver_table right-align-content"})
        
        table_22 = div_car[0].find("table").find_all("tr")
        table_24 = div_car[1].find("table").find_all("tr")
        
        for data in range(1,len(table_22)):
            gold_price_list = append_carat_detail(city_name, data, table_22, gold_price_list)
            gold_price_list = append_carat_detail(city_name, data, table_24, gold_price_list)
    return gold_price_list

# %% [markdown]
# > `list_gold_price_today()` will give us a list of dictionary which will contain all the required data

# %%
def list_gold_price_today():
    city_list = ["ahmedabad","bangalore","bhubaneswar","chandigarh","chennai","coimbatore","delhi","hyderabad","jaipur","kerala","kolkata","lucknow","madurai","mangalore","mumbai","mysore","nagpur","nashik","patna","pune","surat","vadodara","vijayawada","visakhapatnam"]
    gold_price_list = list_of_dict(city_list)
    
    return gold_price_list

# %% [markdown]
# Let us test, if the function is working fine
#
# To do this will call our function `list_gold_price_today`

# %%
gold_price = list_gold_price_today()  #To fetch the data for all the top cities in India
gold_price
# Out:
# [{'City': 'AHMEDABAD',
#   'Carat': '22 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4715',
#   "Yesterday's Price": '₹ 4723',
#   'Daily Price Change': '₹ -8'},
#  {'City': 'AHMEDABAD',
#   'Carat': '24 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 5143',
#   "Yesterday's Price": '₹ 5154',
#   'Daily Price Change': '₹ -11'},
#  {'City': 'AHMEDABAD',
#   'Carat': '22 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 37720',
#   "Yesterday's Price": '₹ 37784',
#   'Daily Price Change': '₹ -64'},
#  {'City': 'AHMEDABAD',
#   'Carat': '24 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 41144',
#   "Yesterday's Price": '₹ 41232',
#   'Daily Price Change': '₹ -88'},
#  {'City': 'AHMEDABAD',
#   'Carat': '22 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47150',
#   "Yesterday's Price": '₹ 47230',
#   'Daily Price Change': '₹ -80'},
#  {'City': 'AHMEDABAD',
#   'Carat': '24 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 51430',
#   "Yesterday's Price": '₹ 51540',
#   'Daily Price Change': '₹ -110'},
#  {'City': 'AHMEDABAD',
#   'Carat': '22 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 471500',
#   "Yesterday's Price": '₹ 472300',
#   'Daily Price Change': '₹ -800'},
#  {'City': 'AHMEDABAD',
#   'Carat': '24 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 514300',
#   "Yesterday's Price": '₹ 515400',
#   'Daily Price Change': '₹ -1100'},
#  {'City': 'BANGALORE',
#   'Carat': '22 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4715',
#   "Yesterday's Price": '₹ 4725',
#   'Daily Price Change': '₹ -10'},
#  {'City': 'BANGALORE',
#   'Carat': '24 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 5143',
#   "Yesterday's Price": '₹ 5154',
#   'Daily Price Change': '₹ -11'},
#  {'City': 'BANGALORE',
#   'Carat': '22 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 37720',
#   "Yesterday's Price": '₹ 37800',
#   'Daily Price Change': '₹ -80'},
#  {'City': 'BANGALORE',
#   'Carat': '24 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 41144',
#   "Yesterday's Price": '₹ 41232',
#   'Daily Price Change': '₹ -88'},
#  {'City': 'BANGALORE',
#   'Carat': '22 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47150',
#   "Yesterday's Price": '₹ 47250',
#   'Daily Price Change': '₹ -100'},
#  {'City': 'BANGALORE',
#   'Carat': '24 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 51430',
#   "Yesterday's Price": '₹ 51540',
#   'Daily Price Change': '₹ -110'},
#  {'City': 'BANGALORE',
#   'Carat': '22 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 471500',
#   "Yesterday's Price": '₹ 472500',
#   'Daily Price Change': '₹ -1000'},
#  {'City': 'BANGALORE',
#   'Carat': '24 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 514300',
#   "Yesterday's Price": '₹ 515400',
#   'Daily Price Change': '₹ -1100'},
#  {'City': 'BHUBANESWAR',
#   'Carat': '22 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4710',
#   "Yesterday's Price": '₹ 4720',
#   'Daily Price Change': '₹ -10'},
#  {'City': 'BHUBANESWAR',
#   'Carat': '24 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 5138',
#   "Yesterday's Price": '₹ 5149',
#   'Daily Price Change': '₹ -11'},
#  {'City': 'BHUBANESWAR',
#   'Carat': '22 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 37680',
#   "Yesterday's Price": '₹ 37760',
#   'Daily Price Change': '₹ -80'},
#  {'City': 'BHUBANESWAR',
#   'Carat': '24 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 41104',
#   "Yesterday's Price": '₹ 41192',
#   'Daily Price Change': '₹ -88'},
#  {'City': 'BHUBANESWAR',
#   'Carat': '22 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47100',
#   "Yesterday's Price": '₹ 47200',
#   'Daily Price Change': '₹ -100'},
#  {'City': 'BHUBANESWAR',
#   'Carat': '24 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 51380',
#   "Yesterday's Price": '₹ 51490',
#   'Daily Price Change': '₹ -110'},
#  {'City': 'BHUBANESWAR',
#   'Carat': '22 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 471000',
#   "Yesterday's Price": '₹ 472000',
#   'Daily Price Change': '₹ -1000'},
#  {'City': 'BHUBANESWAR',
#   'Carat': '24 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 513800',
#   "Yesterday's Price": '₹ 514900',
#   'Daily Price Change': '₹ -1100'},
#  {'City': 'CHANDIGARH',
#   'Carat': '22 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4725',
#   "Yesterday's Price": '₹ 4735',
#   'Daily Price Change': '₹ -10'},
#  {'City': 'CHANDIGARH',
#   'Carat': '24 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 5155',
#   "Yesterday's Price": '₹ 5166',
#   'Daily Price Change': '₹ -11'},
#  {'City': 'CHANDIGARH',
#   'Carat': '22 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 37800',
#   "Yesterday's Price": '₹ 37880',
#   'Daily Price Change': '₹ -80'},
#  {'City': 'CHANDIGARH',
#   'Carat': '24 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 41240',
#   "Yesterday's Price": '₹ 41328',
#   'Daily Price Change': '₹ -88'},
#  {'City': 'CHANDIGARH',
#   'Carat': '22 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47250',
#   "Yesterday's Price": '₹ 47350',
#   'Daily Price Change': '₹ -100'},
#  {'City': 'CHANDIGARH',
#   'Carat': '24 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 51550',
#   "Yesterday's Price": '₹ 51660',
#   'Daily Price Change': '₹ -110'},
#  {'City': 'CHANDIGARH',
#   'Carat': '22 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 472500',
#   "Yesterday's Price": '₹ 473500',
#   'Daily Price Change': '₹ -1000'},
#  {'City': 'CHANDIGARH',
#   'Carat': '24 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 515500',
#   "Yesterday's Price": '₹ 516600',
#   'Daily Price Change': '₹ -1100'},
#  {'City': 'CHENNAI',
#   'Carat': '22 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4795',
#   "Yesterday's Price": '₹ 4815',
#   'Daily Price Change': '₹ -20'},
#  {'City': 'CHENNAI',
#   'Carat': '24 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 5230',
#   "Yesterday's Price": '₹ 5253',
#   'Daily Price Change': '₹ -23'},
#  {'City': 'CHENNAI',
#   'Carat': '22 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 38360',
#   "Yesterday's Price": '₹ 38520',
#   'Daily Price Change': '₹ -160'},
#  {'City': 'CHENNAI',
#   'Carat': '24 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 41840',
#   "Yesterday's Price": '₹ 42024',
#   'Daily Price Change': '₹ -184'},
#  {'City': 'CHENNAI',
#   'Carat': '22 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47950',
#   "Yesterday's Price": '₹ 48150',
#   'Daily Price Change': '₹ -200'},
#  {'City': 'CHENNAI',
#   'Carat': '24 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 52300',
#   "Yesterday's Price": '₹ 52530',
#   'Daily Price Change': '₹ -230'},
#  {'City': 'CHENNAI',
#   'Carat': '22 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 479500',
#   "Yesterday's Price": '₹ 481500',
#   'Daily Price Change': '₹ -2000'},
#  {'City': 'CHENNAI',
#   'Carat': '24 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 523000',
#   "Yesterday's Price": '₹ 525300',
#   'Daily Price Change': '₹ -2300'},
#  {'City': 'COIMBATORE',
#   'Carat': '22 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4795',
#   "Yesterday's Price": '₹ 4815',
#   'Daily Price Change': '₹ -20'},
#  {'City': 'COIMBATORE',
#   'Carat': '24 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 5230',
#   "Yesterday's Price": '₹ 5253',
#   'Daily Price Change': '₹ -23'},
#  {'City': 'COIMBATORE',
#   'Carat': '22 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 38360',
#   "Yesterday's Price": '₹ 38520',
#   'Daily Price Change': '₹ -160'},
#  {'City': 'COIMBATORE',
#   'Carat': '24 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 41840',
#   "Yesterday's Price": '₹ 42024',
#   'Daily Price Change': '₹ -184'},
#  {'City': 'COIMBATORE',
#   'Carat': '22 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47950',
#   "Yesterday's Price": '₹ 48150',
#   'Daily Price Change': '₹ -200'},
#  {'City': 'COIMBATORE',
#   'Carat': '24 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 52300',
#   "Yesterday's Price": '₹ 52530',
#   'Daily Price Change': '₹ -230'},
#  {'City': 'COIMBATORE',
#   'Carat': '22 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 479500',
#   "Yesterday's Price": '₹ 481500',
#   'Daily Price Change': '₹ -2000'},
#  {'City': 'COIMBATORE',
#   'Carat': '24 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 523000',
#   "Yesterday's Price": '₹ 525300',
#   'Daily Price Change': '₹ -2300'},
#  {'City': 'DELHI',
#   'Carat': '22 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4725',
#   "Yesterday's Price": '₹ 4735',
#   'Daily Price Change': '₹ -10'},
#  {'City': 'DELHI',
#   'Carat': '24 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 5155',
#   "Yesterday's Price": '₹ 5166',
#   'Daily Price Change': '₹ -11'},
#  {'City': 'DELHI',
#   'Carat': '22 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 37800',
#   "Yesterday's Price": '₹ 37880',
#   'Daily Price Change': '₹ -80'},
#  {'City': 'DELHI',
#   'Carat': '24 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 41240',
#   "Yesterday's Price": '₹ 41328',
#   'Daily Price Change': '₹ -88'},
#  {'City': 'DELHI',
#   'Carat': '22 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47250',
#   "Yesterday's Price": '₹ 47350',
#   'Daily Price Change': '₹ -100'},
#  {'City': 'DELHI',
#   'Carat': '24 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 51550',
#   "Yesterday's Price": '₹ 51660',
#   'Daily Price Change': '₹ -110'},
#  {'City': 'DELHI',
#   'Carat': '22 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 472500',
#   "Yesterday's Price": '₹ 473500',
#   'Daily Price Change': '₹ -1000'},
#  {'City': 'DELHI',
#   'Carat': '24 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 515500',
#   "Yesterday's Price": '₹ 516600',
#   'Daily Price Change': '₹ -1100'},
#  {'City': 'HYDERABAD',
#   'Carat': '22 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4710',
#   "Yesterday's Price": '₹ 4720',
#   'Daily Price Change': '₹ -10'},
#  {'City': 'HYDERABAD',
#   'Carat': '24 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 5138',
#   "Yesterday's Price": '₹ 5149',
#   'Daily Price Change': '₹ -11'},
#  {'City': 'HYDERABAD',
#   'Carat': '22 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 37680',
#   "Yesterday's Price": '₹ 37760',
#   'Daily Price Change': '₹ -80'},
#  {'City': 'HYDERABAD',
#   'Carat': '24 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 41104',
#   "Yesterday's Price": '₹ 41192',
#   'Daily Price Change': '₹ -88'},
#  {'City': 'HYDERABAD',
#   'Carat': '22 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47100',
#   "Yesterday's Price": '₹ 47200',
#   'Daily Price Change': '₹ -100'},
#  {'City': 'HYDERABAD',
#   'Carat': '24 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 51380',
#   "Yesterday's Price": '₹ 51490',
#   'Daily Price Change': '₹ -110'},
#  {'City': 'HYDERABAD',
#   'Carat': '22 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 471000',
#   "Yesterday's Price": '₹ 472000',
#   'Daily Price Change': '₹ -1000'},
#  {'City': 'HYDERABAD',
#   'Carat': '24 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 513800',
#   "Yesterday's Price": '₹ 514900',
#   'Daily Price Change': '₹ -1100'},
#  {'City': 'JAIPUR',
#   'Carat': '22 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4725',
#   "Yesterday's Price": '₹ 4735',
#   'Daily Price Change': '₹ -10'},
#  {'City': 'JAIPUR',
#   'Carat': '24 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 5155',
#   "Yesterday's Price": '₹ 5166',
#   'Daily Price Change': '₹ -11'},
#  {'City': 'JAIPUR',
#   'Carat': '22 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 37800',
#   "Yesterday's Price": '₹ 37880',
#   'Daily Price Change': '₹ -80'},
#  {'City': 'JAIPUR',
#   'Carat': '24 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 41240',
#   "Yesterday's Price": '₹ 41328',
#   'Daily Price Change': '₹ -88'},
#  {'City': 'JAIPUR',
#   'Carat': '22 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47250',
#   "Yesterday's Price": '₹ 47350',
#   'Daily Price Change': '₹ -100'},
#  {'City': 'JAIPUR',
#   'Carat': '24 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 51550',
#   "Yesterday's Price": '₹ 51660',
#   'Daily Price Change': '₹ -110'},
#  {'City': 'JAIPUR',
#   'Carat': '22 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 472500',
#   "Yesterday's Price": '₹ 473500',
#   'Daily Price Change': '₹ -1000'},
#  {'City': 'JAIPUR',
#   'Carat': '24 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 515500',
#   "Yesterday's Price": '₹ 516600',
#   'Daily Price Change': '₹ -1100'},
#  {'City': 'KERALA',
#   'Carat': '22 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4710',
#   "Yesterday's Price": '₹ 4720',
#   'Daily Price Change': '₹ -10'},
#  {'City': 'KERALA',
#   'Carat': '24 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 5138',
#   "Yesterday's Price": '₹ 5149',
#   'Daily Price Change': '₹ -11'},
#  {'City': 'KERALA',
#   'Carat': '22 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 37680',
#   "Yesterday's Price": '₹ 37760',
#   'Daily Price Change': '₹ -80'},
#  {'City': 'KERALA',
#   'Carat': '24 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 41104',
#   "Yesterday's Price": '₹ 41192',
#   'Daily Price Change': '₹ -88'},
#  {'City': 'KERALA',
#   'Carat': '22 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47100',
#   "Yesterday's Price": '₹ 47200',
#   'Daily Price Change': '₹ -100'},
#  {'City': 'KERALA',
#   'Carat': '24 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 51380',
#   "Yesterday's Price": '₹ 51490',
#   'Daily Price Change': '₹ -110'},
#  {'City': 'KERALA',
#   'Carat': '22 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 471000',
#   "Yesterday's Price": '₹ 472000',
#   'Daily Price Change': '₹ -1000'},
#  {'City': 'KERALA',
#   'Carat': '24 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 513800',
#   "Yesterday's Price": '₹ 514900',
#   'Daily Price Change': '₹ -1100'},
#  {'City': 'KOLKATA',
#   'Carat': '22 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4710',
#   "Yesterday's Price": '₹ 4720',
#   'Daily Price Change': '₹ -10'},
#  {'City': 'KOLKATA',
#   'Carat': '24 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 5138',
#   "Yesterday's Price": '₹ 5149',
#   'Daily Price Change': '₹ -11'},
#  {'City': 'KOLKATA',
#   'Carat': '22 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 37680',
#   "Yesterday's Price": '₹ 37760',
#   'Daily Price Change': '₹ -80'},
#  {'City': 'KOLKATA',
#   'Carat': '24 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 41104',
#   "Yesterday's Price": '₹ 41192',
#   'Daily Price Change': '₹ -88'},
#  {'City': 'KOLKATA',
#   'Carat': '22 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47100',
#   "Yesterday's Price": '₹ 47200',
#   'Daily Price Change': '₹ -100'},
#  {'City': 'KOLKATA',
#   'Carat': '24 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 51380',
#   "Yesterday's Price": '₹ 51490',
#   'Daily Price Change': '₹ -110'},
#  {'City': 'KOLKATA',
#   'Carat': '22 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 471000',
#   "Yesterday's Price": '₹ 472000',
#   'Daily Price Change': '₹ -1000'},
#  {'City': 'KOLKATA',
#   'Carat': '24 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 513800',
#   "Yesterday's Price": '₹ 514900',
#   'Daily Price Change': '₹ -1100'},
#  {'City': 'LUCKNOW',
#   'Carat': '22 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4725',
#   "Yesterday's Price": '₹ 4735',
#   'Daily Price Change': '₹ -10'},
#  {'City': 'LUCKNOW',
#   'Carat': '24 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 5155',
#   "Yesterday's Price": '₹ 5166',
#   'Daily Price Change': '₹ -11'},
#  {'City': 'LUCKNOW',
#   'Carat': '22 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 37800',
#   "Yesterday's Price": '₹ 37880',
#   'Daily Price Change': '₹ -80'},
#  {'City': 'LUCKNOW',
#   'Carat': '24 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 41240',
#   "Yesterday's Price": '₹ 41328',
#   'Daily Price Change': '₹ -88'},
#  {'City': 'LUCKNOW',
#   'Carat': '22 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47250',
#   "Yesterday's Price": '₹ 47350',
#   'Daily Price Change': '₹ -100'},
#  {'City': 'LUCKNOW',
#   'Carat': '24 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 51550',
#   "Yesterday's Price": '₹ 51660',
#   'Daily Price Change': '₹ -110'},
#  {'City': 'LUCKNOW',
#   'Carat': '22 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 472500',
#   "Yesterday's Price": '₹ 473500',
#   'Daily Price Change': '₹ -1000'},
#  {'City': 'LUCKNOW',
#   'Carat': '24 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 515500',
#   "Yesterday's Price": '₹ 516600',
#   'Daily Price Change': '₹ -1100'},
#  {'City': 'MADURAI',
#   'Carat': '22 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4795',
#   "Yesterday's Price": '₹ 4815',
#   'Daily Price Change': '₹ -20'},
#  {'City': 'MADURAI',
#   'Carat': '24 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 5230',
#   "Yesterday's Price": '₹ 5253',
#   'Daily Price Change': '₹ -23'},
#  {'City': 'MADURAI',
#   'Carat': '22 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 38360',
#   "Yesterday's Price": '₹ 38520',
#   'Daily Price Change': '₹ -160'},
#  {'City': 'MADURAI',
#   'Carat': '24 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 41840',
#   "Yesterday's Price": '₹ 42024',
#   'Daily Price Change': '₹ -184'},
#  {'City': 'MADURAI',
#   'Carat': '22 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47950',
#   "Yesterday's Price": '₹ 48150',
#   'Daily Price Change': '₹ -200'},
#  {'City': 'MADURAI',
#   'Carat': '24 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 52300',
#   "Yesterday's Price": '₹ 52530',
#   'Daily Price Change': '₹ -230'},
#  {'City': 'MADURAI',
#   'Carat': '22 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 479500',
#   "Yesterday's Price": '₹ 481500',
#   'Daily Price Change': '₹ -2000'},
#  {'City': 'MADURAI',
#   'Carat': '24 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 523000',
#   "Yesterday's Price": '₹ 525300',
#   'Daily Price Change': '₹ -2300'},
#  {'City': 'MANGALORE',
#   'Carat': '22 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4715',
#   "Yesterday's Price": '₹ 4725',
#   'Daily Price Change': '₹ -10'},
#  {'City': 'MANGALORE',
#   'Carat': '24 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 5143',
#   "Yesterday's Price": '₹ 5154',
#   'Daily Price Change': '₹ -11'},
#  {'City': 'MANGALORE',
#   'Carat': '22 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 37720',
#   "Yesterday's Price": '₹ 37800',
#   'Daily Price Change': '₹ -80'},
#  {'City': 'MANGALORE',
#   'Carat': '24 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 41144',
#   "Yesterday's Price": '₹ 41232',
#   'Daily Price Change': '₹ -88'},
#  {'City': 'MANGALORE',
#   'Carat': '22 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47150',
#   "Yesterday's Price": '₹ 47250',
#   'Daily Price Change': '₹ -100'},
#  {'City': 'MANGALORE',
#   'Carat': '24 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 51430',
#   "Yesterday's Price": '₹ 51540',
#   'Daily Price Change': '₹ -110'},
#  {'City': 'MANGALORE',
#   'Carat': '22 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 471500',
#   "Yesterday's Price": '₹ 472500',
#   'Daily Price Change': '₹ -1000'},
#  {'City': 'MANGALORE',
#   'Carat': '24 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 514300',
#   "Yesterday's Price": '₹ 515400',
#   'Daily Price Change': '₹ -1100'},
#  {'City': 'MUMBAI',
#   'Carat': '22 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4710',
#   "Yesterday's Price": '₹ 4720',
#   'Daily Price Change': '₹ -10'},
#  {'City': 'MUMBAI',
#   'Carat': '24 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 5138',
#   "Yesterday's Price": '₹ 5149',
#   'Daily Price Change': '₹ -11'},
#  {'City': 'MUMBAI',
#   'Carat': '22 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 37680',
#   "Yesterday's Price": '₹ 37760',
#   'Daily Price Change': '₹ -80'},
#  {'City': 'MUMBAI',
#   'Carat': '24 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 41104',
#   "Yesterday's Price": '₹ 41192',
#   'Daily Price Change': '₹ -88'},
#  {'City': 'MUMBAI',
#   'Carat': '22 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47100',
#   "Yesterday's Price": '₹ 47200',
#   'Daily Price Change': '₹ -100'},
#  {'City': 'MUMBAI',
#   'Carat': '24 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 51380',
#   "Yesterday's Price": '₹ 51490',
#   'Daily Price Change': '₹ -110'},
#  {'City': 'MUMBAI',
#   'Carat': '22 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 471000',
#   "Yesterday's Price": '₹ 472000',
#   'Daily Price Change': '₹ -1000'},
#  {'City': 'MUMBAI',
#   'Carat': '24 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 513800',
#   "Yesterday's Price": '₹ 514900',
#   'Daily Price Change': '₹ -1100'},
#  {'City': 'MYSORE',
#   'Carat': '22 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4715',
#   "Yesterday's Price": '₹ 4725',
#   'Daily Price Change': '₹ -10'},
#  {'City': 'MYSORE',
#   'Carat': '24 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 5143',
#   "Yesterday's Price": '₹ 5154',
#   'Daily Price Change': '₹ -11'},
#  {'City': 'MYSORE',
#   'Carat': '22 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 37720',
#   "Yesterday's Price": '₹ 37800',
#   'Daily Price Change': '₹ -80'},
#  {'City': 'MYSORE',
#   'Carat': '24 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 41144',
#   "Yesterday's Price": '₹ 41232',
#   'Daily Price Change': '₹ -88'},
#  {'City': 'MYSORE',
#   'Carat': '22 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47150',
#   "Yesterday's Price": '₹ 47250',
#   'Daily Price Change': '₹ -100'},
#  {'City': 'MYSORE',
#   'Carat': '24 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 51430',
#   "Yesterday's Price": '₹ 51540',
#   'Daily Price Change': '₹ -110'},
#  {'City': 'MYSORE',
#   'Carat': '22 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 471500',
#   "Yesterday's Price": '₹ 472500',
#   'Daily Price Change': '₹ -1000'},
#  {'City': 'MYSORE',
#   'Carat': '24 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 514300',
#   "Yesterday's Price": '₹ 515400',
#   'Daily Price Change': '₹ -1100'},
#  {'City': 'NAGPUR',
#   'Carat': '22 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4713',
#   "Yesterday's Price": '₹ 4723',
#   'Daily Price Change': '₹ -10'},
#  {'City': 'NAGPUR',
#   'Carat': '24 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 5141',
#   "Yesterday's Price": '₹ 5157',
#   'Daily Price Change': '₹ -16'},
#  {'City': 'NAGPUR',
#   'Carat': '22 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 37704',
#   "Yesterday's Price": '₹ 37784',
#   'Daily Price Change': '₹ -80'},
#  {'City': 'NAGPUR',
#   'Carat': '24 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 41128',
#   "Yesterday's Price": '₹ 41256',
#   'Daily Price Change': '₹ -128'},
#  {'City': 'NAGPUR',
#   'Carat': '22 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47130',
#   "Yesterday's Price": '₹ 47230',
#   'Daily Price Change': '₹ -100'},
#  {'City': 'NAGPUR',
#   'Carat': '24 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 51410',
#   "Yesterday's Price": '₹ 51570',
#   'Daily Price Change': '₹ -160'},
#  {'City': 'NAGPUR',
#   'Carat': '22 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 471300',
#   "Yesterday's Price": '₹ 472300',
#   'Daily Price Change': '₹ -1000'},
#  {'City': 'NAGPUR',
#   'Carat': '24 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 514100',
#   "Yesterday's Price": '₹ 515700',
#   'Daily Price Change': '₹ -1600'},
#  {'City': 'NASHIK',
#   'Carat': '22 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4713',
#   "Yesterday's Price": '₹ 4723',
#   'Daily Price Change': '₹ -10'},
#  {'City': 'NASHIK',
#   'Carat': '24 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 5141',
#   "Yesterday's Price": '₹ 5157',
#   'Daily Price Change': '₹ -16'},
#  {'City': 'NASHIK',
#   'Carat': '22 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 37704',
#   "Yesterday's Price": '₹ 37784',
#   'Daily Price Change': '₹ -80'},
#  {'City': 'NASHIK',
#   'Carat': '24 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 41128',
#   "Yesterday's Price": '₹ 41256',
#   'Daily Price Change': '₹ -128'},
#  {'City': 'NASHIK',
#   'Carat': '22 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47130',
#   "Yesterday's Price": '₹ 47230',
#   'Daily Price Change': '₹ -100'},
#  {'City': 'NASHIK',
#   'Carat': '24 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 51410',
#   "Yesterday's Price": '₹ 51570',
#   'Daily Price Change': '₹ -160'},
#  {'City': 'NASHIK',
#   'Carat': '22 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 471300',
#   "Yesterday's Price": '₹ 472300',
#   'Daily Price Change': '₹ -1000'},
#  {'City': 'NASHIK',
#   'Carat': '24 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 514100',
#   "Yesterday's Price": '₹ 515700',
#   'Daily Price Change': '₹ -1600'},
#  {'City': 'PATNA',
#   'Carat': '22 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4713',
#   "Yesterday's Price": '₹ 4723',
#   'Daily Price Change': '₹ -10'},
#  {'City': 'PATNA',
#   'Carat': '24 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 5141',
#   "Yesterday's Price": '₹ 5157',
#   'Daily Price Change': '₹ -16'},
#  {'City': 'PATNA',
#   'Carat': '22 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 37704',
#   "Yesterday's Price": '₹ 37784',
#   'Daily Price Change': '₹ -80'},
#  {'City': 'PATNA',
#   'Carat': '24 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 41128',
#   "Yesterday's Price": '₹ 41256',
#   'Daily Price Change': '₹ -128'},
#  {'City': 'PATNA',
#   'Carat': '22 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47130',
#   "Yesterday's Price": '₹ 47230',
#   'Daily Price Change': '₹ -100'},
#  {'City': 'PATNA',
#   'Carat': '24 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 51410',
#   "Yesterday's Price": '₹ 51570',
#   'Daily Price Change': '₹ -160'},
#  {'City': 'PATNA',
#   'Carat': '22 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 471300',
#   "Yesterday's Price": '₹ 472300',
#   'Daily Price Change': '₹ -1000'},
#  {'City': 'PATNA',
#   'Carat': '24 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 514100',
#   "Yesterday's Price": '₹ 515700',
#   'Daily Price Change': '₹ -1600'},
#  {'City': 'PUNE',
#   'Carat': '22 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4713',
#   "Yesterday's Price": '₹ 4723',
#   'Daily Price Change': '₹ -10'},
#  {'City': 'PUNE',
#   'Carat': '24 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 5141',
#   "Yesterday's Price": '₹ 5157',
#   'Daily Price Change': '₹ -16'},
#  {'City': 'PUNE',
#   'Carat': '22 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 37704',
#   "Yesterday's Price": '₹ 37784',
#   'Daily Price Change': '₹ -80'},
#  {'City': 'PUNE',
#   'Carat': '24 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 41128',
#   "Yesterday's Price": '₹ 41256',
#   'Daily Price Change': '₹ -128'},
#  {'City': 'PUNE',
#   'Carat': '22 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47130',
#   "Yesterday's Price": '₹ 47230',
#   'Daily Price Change': '₹ -100'},
#  {'City': 'PUNE',
#   'Carat': '24 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 51410',
#   "Yesterday's Price": '₹ 51570',
#   'Daily Price Change': '₹ -160'},
#  {'City': 'PUNE',
#   'Carat': '22 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 471300',
#   "Yesterday's Price": '₹ 472300',
#   'Daily Price Change': '₹ -1000'},
#  {'City': 'PUNE',
#   'Carat': '24 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 514100',
#   "Yesterday's Price": '₹ 515700',
#   'Daily Price Change': '₹ -1600'},
#  {'City': 'SURAT',
#   'Carat': '22 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4715',
#   "Yesterday's Price": '₹ 4725',
#   'Daily Price Change': '₹ -10'},
#  {'City': 'SURAT',
#   'Carat': '24 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 5143',
#   "Yesterday's Price": '₹ 5154',
#   'Daily Price Change': '₹ -11'},
#  {'City': 'SURAT',
#   'Carat': '22 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 37720',
#   "Yesterday's Price": '₹ 37800',
#   'Daily Price Change': '₹ -80'},
#  {'City': 'SURAT',
#   'Carat': '24 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 41144',
#   "Yesterday's Price": '₹ 41232',
#   'Daily Price Change': '₹ -88'},
#  {'City': 'SURAT',
#   'Carat': '22 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47150',
#   "Yesterday's Price": '₹ 47250',
#   'Daily Price Change': '₹ -100'},
#  {'City': 'SURAT',
#   'Carat': '24 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 51430',
#   "Yesterday's Price": '₹ 51540',
#   'Daily Price Change': '₹ -110'},
#  {'City': 'SURAT',
#   'Carat': '22 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 471500',
#   "Yesterday's Price": '₹ 472500',
#   'Daily Price Change': '₹ -1000'},
#  {'City': 'SURAT',
#   'Carat': '24 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 514300',
#   "Yesterday's Price": '₹ 515400',
#   'Daily Price Change': '₹ -1100'},
#  {'City': 'VADODARA',
#   'Carat': '22 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4713',
#   "Yesterday's Price": '₹ 4723',
#   'Daily Price Change': '₹ -10'},
#  {'City': 'VADODARA',
#   'Carat': '24 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 5141',
#   "Yesterday's Price": '₹ 5157',
#   'Daily Price Change': '₹ -16'},
#  {'City': 'VADODARA',
#   'Carat': '22 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 37704',
#   "Yesterday's Price": '₹ 37784',
#   'Daily Price Change': '₹ -80'},
#  {'City': 'VADODARA',
#   'Carat': '24 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 41128',
#   "Yesterday's Price": '₹ 41256',
#   'Daily Price Change': '₹ -128'},
#  {'City': 'VADODARA',
#   'Carat': '22 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47130',
#   "Yesterday's Price": '₹ 47230',
#   'Daily Price Change': '₹ -100'},
#  {'City': 'VADODARA',
#   'Carat': '24 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 51410',
#   "Yesterday's Price": '₹ 51570',
#   'Daily Price Change': '₹ -160'},
#  {'City': 'VADODARA',
#   'Carat': '22 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 471300',
#   "Yesterday's Price": '₹ 472300',
#   'Daily Price Change': '₹ -1000'},
#  {'City': 'VADODARA',
#   'Carat': '24 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 514100',
#   "Yesterday's Price": '₹ 515700',
#   'Daily Price Change': '₹ -1600'},
#  {'City': 'VIJAYAWADA',
#   'Carat': '22 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4710',
#   "Yesterday's Price": '₹ 4720',
#   'Daily Price Change': '₹ -10'},
#  {'City': 'VIJAYAWADA',
#   'Carat': '24 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 5138',
#   "Yesterday's Price": '₹ 5149',
#   'Daily Price Change': '₹ -11'},
#  {'City': 'VIJAYAWADA',
#   'Carat': '22 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 37680',
#   "Yesterday's Price": '₹ 37760',
#   'Daily Price Change': '₹ -80'},
#  {'City': 'VIJAYAWADA',
#   'Carat': '24 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 41104',
#   "Yesterday's Price": '₹ 41192',
#   'Daily Price Change': '₹ -88'},
#  {'City': 'VIJAYAWADA',
#   'Carat': '22 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47100',
#   "Yesterday's Price": '₹ 47200',
#   'Daily Price Change': '₹ -100'},
#  {'City': 'VIJAYAWADA',
#   'Carat': '24 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 51380',
#   "Yesterday's Price": '₹ 51490',
#   'Daily Price Change': '₹ -110'},
#  {'City': 'VIJAYAWADA',
#   'Carat': '22 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 471000',
#   "Yesterday's Price": '₹ 472000',
#   'Daily Price Change': '₹ -1000'},
#  {'City': 'VIJAYAWADA',
#   'Carat': '24 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 513800',
#   "Yesterday's Price": '₹ 514900',
#   'Daily Price Change': '₹ -1100'},
#  {'City': 'VISAKHAPATNAM',
#   'Carat': '22 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 4710',
#   "Yesterday's Price": '₹ 4720',
#   'Daily Price Change': '₹ -10'},
#  {'City': 'VISAKHAPATNAM',
#   'Carat': '24 Carat',
#   'Gram': '1 gram',
#   "Today's Price": '₹ 5138',
#   "Yesterday's Price": '₹ 5149',
#   'Daily Price Change': '₹ -11'},
#  {'City': 'VISAKHAPATNAM',
#   'Carat': '22 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 37680',
#   "Yesterday's Price": '₹ 37760',
#   'Daily Price Change': '₹ -80'},
#  {'City': 'VISAKHAPATNAM',
#   'Carat': '24 Carat',
#   'Gram': '8 gram',
#   "Today's Price": '₹ 41104',
#   "Yesterday's Price": '₹ 41192',
#   'Daily Price Change': '₹ -88'},
#  {'City': 'VISAKHAPATNAM',
#   'Carat': '22 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 47100',
#   "Yesterday's Price": '₹ 47200',
#   'Daily Price Change': '₹ -100'},
#  {'City': 'VISAKHAPATNAM',
#   'Carat': '24 Carat',
#   'Gram': '10 gram',
#   "Today's Price": '₹ 51380',
#   "Yesterday's Price": '₹ 51490',
#   'Daily Price Change': '₹ -110'},
#  {'City': 'VISAKHAPATNAM',
#   'Carat': '22 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 471000',
#   "Yesterday's Price": '₹ 472000',
#   'Daily Price Change': '₹ -1000'},
#  {'City': 'VISAKHAPATNAM',
#   'Carat': '24 Carat',
#   'Gram': '100 gram',
#   "Today's Price": '₹ 513800',
#   "Yesterday's Price": '₹ 514900',
#   'Daily Price Change': '₹ -1100'}]

# %%
jovian.commit(filename="web-scraping-project.ipynb")
# Out:
# [jovian] Updating notebook "abhishek-mehta2k/web-scraping-project" on https://jovian.ai
# [jovian] Committed successfully! https://jovian.ai/abhishek-mehta2k/web-scraping-project
# 'https://jovian.ai/abhishek-mehta2k/web-scraping-project'

# %% [markdown]
# **Now that we have the information for all the cities, Let us convert this dictionary to a DataFrame just like we did previously to easily work with the tabular data using Pandas.**

# %%
gold_price_today_df = pd.DataFrame(gold_price)

# %%
gold_price_today_df
# Out:
#               City     Carat      Gram Today's Price Yesterday's Price  \
# 0        AHMEDABAD  22 Carat    1 gram        ₹ 4715            ₹ 4723
# 1        AHMEDABAD  24 Carat    1 gram        ₹ 5143            ₹ 5154
# 2        AHMEDABAD  22 Carat    8 gram       ₹ 37720           ₹ 37784
# 3        AHMEDABAD  24 Carat    8 gram       ₹ 41144           ₹ 41232
# 4        AHMEDABAD  22 Carat   10 gram       ₹ 47150           ₹ 47230
# ..             ...       ...       ...           ...               ...
# 187  VISAKHAPATNAM  24 Carat    8 gram       ₹ 41104           ₹ 41192
# 188  VISAKHAPATNAM  22 Carat   10 gram       ₹ 47100           ₹ 47200
# 189  VISAKHAPATNAM  24 Carat   10 gram       ₹ 51380           ₹ 51490
# 190  VISAKHAPATNAM  22 Carat  100 gram      ₹ 471000          ₹ 472000
# 191  VISAKHAPATNAM  24 Carat  100 gram      ₹ 513800          ₹ 514900
#
#     Daily Price Change
# 0                 ₹ -8
# 1                ₹ -11
# 2                ₹ -64
# 3                ₹ -88
# 4                ₹ -80
# ..                 ...
# 187              ₹ -88
# 188             ₹ -100
# 189             ₹ -110
# 190            ₹ -1000
# 191            ₹ -1100
#
# [192 rows x 6 columns]

# %% [markdown]
# > Let us now save this DataFrame as a CSV file.
# And for that we a write a funciton `write_csv()`

# %%
def write_csv(items,path):
    with open(path,'w',encoding="utf-8") as f:
        if len(items) == 0:
            return
        
        #write the headers
        headers = list(items[0].keys())
        f.write(','.join(headers) + '\n')
        
        for item in items:
            values = []
            for header in headers:
                values.append(str(item.get(header,"")))
            f.write(','.join(values) + '\n')

# %% [markdown]
# > Using `write_csv()` funciton we will write your `gold_price` into a `.csv' file

# %%
print("Converting dictionary to a csv file")
write_csv(gold_price,"todayprice.csv")
print("Successfully created the csv file ")
# Out:
# Converting dictionary to a csv file
# Successfully created the csv file

# %% [markdown]
# Now you can successfully see the `todayprice.csv` file into `File-->Open`
#
# ![](https://imgur.com/SneDpeo.png)

# %% [markdown]
# ### Let's write a single funciton which will `Parse` and also write back to a `CSV` file

# %%
def get_today_price():
    #FUNCTION CALL `install_libraries()`
    install_libraries()
    from datetime import date

    path = None
    if path == None:
        path = date.today().strftime("%B-%d-%Y") + '-gold-price.csv'
    print("Writting Today's Gold Price to the file",path)

    #FUNCTION CALL `write_csv`
    write_csv(list_gold_price_today(),path)

    print("Today's Gold Price writtten to file",path)

    #Printing the csv file
    print("Printing your csv file",path)
    return pd.read_csv(path)

# %% [markdown]
# Let us test, if the function is working fine
#
# To do this will call our function `get_today_price()`

# %%
df = get_today_price()
df
# Out:
# Successfully installed all the required Libraries
# Writting Today's Gold Price to the file August-01-2022-gold-price.csv
# Today's Gold Price writtten to file August-01-2022-gold-price.csv
# Printing your csv file August-01-2022-gold-price.csv
#               City     Carat      Gram Today's Price Yesterday's Price  \
# 0        AHMEDABAD  22 Carat    1 gram        ₹ 4715            ₹ 4723
# 1        AHMEDABAD  24 Carat    1 gram        ₹ 5143            ₹ 5154
# 2        AHMEDABAD  22 Carat    8 gram       ₹ 37720           ₹ 37784
# 3        AHMEDABAD  24 Carat    8 gram       ₹ 41144           ₹ 41232
# 4        AHMEDABAD  22 Carat   10 gram       ₹ 47150           ₹ 47230
# ..             ...       ...       ...           ...               ...
# 187  VISAKHAPATNAM  24 Carat    8 gram       ₹ 41104           ₹ 41192
# 188  VISAKHAPATNAM  22 Carat   10 gram       ₹ 47100           ₹ 47200
# 189  VISAKHAPATNAM  24 Carat   10 gram       ₹ 51380           ₹ 51490
# 190  VISAKHAPATNAM  22 Carat  100 gram      ₹ 471000          ₹ 472000
# 191  VISAKHAPATNAM  24 Carat  100 gram      ₹ 513800          ₹ 514900
#
#     Daily Price Change
# 0                 ₹ -8
# 1                ₹ -11
# 2                ₹ -64
# 3                ₹ -88
# 4                ₹ -80
# ..                 ...
# 187              ₹ -88
# 188             ₹ -100
# 189             ₹ -110
# 190            ₹ -1000
# 191            ₹ -1100
#
# [192 rows x 6 columns]

# %%
from datetime import date
jovian.commit(filename="web-scraping-project.ipynb",outputs=[date.today().strftime("%B-%d-%Y") + '-gold-price.csv'])

# %% [markdown]
# ## Summary
#
# Finally, we have managed to `parse` 'Good Returns Website' to get our hands on very **interesting and insightful data** when it comes to the Finance/Money.
# We have saved all the information we could extract from that website for our needs in a `CSV` file using which we can further get answers to a lot of questions we may want to ask, e.g - `Which City is having the highest Gold Price in India?, What was the price of gold in Mumbai on 10 July 2022?`
# ![](https://imgur.com/nVZjok9.png)

# %% [markdown]
# Let us look at the steps that we took from start to finish :
#
# 1. We downloaded the webpage using `requests`
#
#
# 2. We `parsed` the HTML source code using `BeautifulSoup` library and extracted the desired infromation, i.e.
# * The City Name
# * Price and other details of the Gold in that particular city
#
#
# 3. We created a `DataFrame` using `Pandas` for `Python Lists` that we derived from the previous step
#
#
# 4. We extracted detailed information of gold rates for top cities in India , such as :
# * Today's Price
# * Yesterday's Price
# * Price based on Weights(gram)
# * Daily Price Change
#
# 5. We then created a `Python Dictionary` to save all these details
#
#
# 6. We converted the python dictionary into `Pandas DataFrames`
#
#
# 8. With our DataFrame in hand, we then converted it into a single `CSV` file, which was the goal of our project.

# %% [markdown]
# ## Future Work

# %% [markdown]
# We can now work forward to explore this data more and more to fetch meaningful information out of it.
#
# With all the insights , and further analysis into the data, we can have answers to a lot of questions like -
# * Which city is having the highest Gold Rate in India?
# * The Top Cities based upon Gold Rates?
# * Which City is having a consistent change in Gold Rates?
#
# And the list goes on..
#
# > In the future, I would like to work to make this `DataSet` even richer with more data.
# I would then like to work on analysing the entire data, to know a lot more about gold rates and their trends than I currently know.

# %% [markdown]
# ## References
#
#
# [1] Python offical documentation. https://docs.python.org/3/
#
#
# [2] Requests library. https://pypi.org/project/requests/
#
#
# [3] Beautiful Soup documentation. https://www.crummy.com/software/BeautifulSoup/bs4/doc/
#
#
# [4] Aakash N S, Introduction to Web Scraping, 2021. https://jovian.ai/aakashns/python-web-scraping-and-rest-api
#
#
# [5] Pandas library documentation. https://pandas.pydata.org/docs/
#
#
# [6] Good Returns Website. https://www.goodreturns.in/
#
#
# [7] Web Scraping Article. https://codingshiksha.com/python/python-3-web-scraping-script-to-get-realtime-price-of-gold-in-inr-currency-from-google-search-using-beautifulsoup4-library-full-project-for-beginners/
#
# [8] Working with Jupyter Notebook https://towardsdatascience.com/write-markdown-latex-in-the-jupyter-notebook-10985edb91fd
